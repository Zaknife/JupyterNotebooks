# %%
from ipywidgets import *
import pandas as pd
import numpy as np
import collections
import matplotlib
import os
from natsort import natsorted
from numpy.lib.scimath import sqrt as sqrt
from scipy.interpolate import griddata
import plotly.plotly as py
import plotly.tools as tls
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
from plotly.offline import plot
from plotly.graph_objs import Scatter
from IPython.display import Image
py.sign_in('GPMazur', '7xjm7bhoup')
init_notebook_mode()
# Out:
# <script type='text/javascript'>if(!window.Plotly){define('plotly', function(require, exports, module) {/**
# * plotly.js v1.16.2
# * Copyright 2012-2016, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# ...

# %%
dir="C:\\Users\\Grzegorz Mazur\\Google Drive\\StudiaDoktoranckie\\2016\\CriticalGaMnAs\\E37\\"

# %%
Image(filename=dir+'E37xh.jpg')
# <img src="files/dir/E37xh.jpg">

# %%
FC5=pd.read_csv(dir+'E37x [s=h] FC(5 Oe) 12Jun16_garlic.rso.dat',sep=',',header=20,error_bad_lines=False)
FC2=pd.read_csv(dir+'E37x [s=h] FC(2 Oe) 12Jun16_garlic.rso.dat',sep=',',header=20,error_bad_lines=False)
TRM5=pd.read_csv(dir+'E37x [s=h] TRM(5 Oe) 12Jun16_garlic.rso.dat',sep=',',header=20,error_bad_lines=False)
TRM2=pd.read_csv(dir+'E37x [s=h] TRM(2 Oe) 12Jun16_garlic.rso.dat',sep=',',header=20,error_bad_lines=False)
m1kOe=pd.read_csv(dir+'E37x [s=h] m(1kOe) 12Jun16_garlic.rso.dat',sep=',',header=20,error_bad_lines=False)
FC5Sapph=pd.read_csv(dir+'SapphireHolder//'+'E37x [s=h] FC(5 Oe) on  SapphireHolder 30Sep16_garlic.rso.dat',sep=',',header=20,error_bad_lines=False)
FC2Sapph=pd.read_csv(dir+'SapphireHolder//'+'E37x [s=h] FC(2 Oe) on  SapphireHolder 30Sep16_garlic.rso.dat',sep=',',header=20,error_bad_lines=False)
TRM5Sapph=pd.read_csv(dir+'SapphireHolder//'+'E37x [s=h] TRM(5 Oe) on  SapphireHolder 30Sep16_garlic.rso.dat',sep=',',header=20,error_bad_lines=False)
TRM2Sapph=pd.read_csv(dir+'SapphireHolder//'+'E37x [s=h] TRM(2 Oe) on  SapphireHolder 30Sep16_garlic.rso.dat',sep=',',header=20,error_bad_lines=False)

# %%
iplot([{"x":FC2['Temperature (K)'],"y":FC2['Long Moment (emu)']*1e8,'name':'FC2','mode':'markers+lines'},
       {"x":FC5['Temperature (K)'],"y":FC5['Long Moment (emu)']*1e8,'name':'FC5','mode':'markers+lines'},
       {"x":FC2Sapph['Temperature (K)'],"y":FC2Sapph['Long Moment (emu)']*1e8,'name':'FC2SapphireHolder','mode':'markers+lines'},
       {"x":FC5Sapph['Temperature (K)'],"y":FC5Sapph['Long Moment (emu)']*1e8,'name':'FC5SapphireHolder','mode':'markers+lines'}
       ])
# Out:
# <div id="6c046017-8681-4f81-ac20-c92e65ac07be" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6c046017-8681-4f81-ac20-c92e65ac07be", [{"x": [177.0023, 176.4158, 176.072, 175.7129, 175.2955, 174.87, 174.4844, 174.0814, 173.6579, 173.2623, 172.8408, 172.4398, 172.0435, 171.6642, 171.2487, 170.8404, 170.4132, 170.0102, 169.636, 169.2364, 168.7858, 168.4291, 167.9901, 167.6172, 167.2076, 166.8229, 166.3991, 165.9938, 165.6193, 165.2008, 164.8094, 164.3954, 164.0156, 163.5896, 163.1968, 162.7952, 162.4086, 161.991, 161.5721, 161.2073, 160.7949, 160.4005, 160.0011, 159.5933, 159.1943, 158.7881, 158.3855, 157.9917, 157.5832, 157.1873, 156.7939, 156.3829, 155.9722, 155.5836, 155.1684, 154.7796, 154.3869, 153.9877, 153.5815, 153.1885, 152.7773, 152.3803, 151.9741, 151.5792, 151.1842, 150.7656, 150.3816, 14
# ...

# %%
iplot([{"x":TRM5['Temperature (K)'],"y":TRM5['Long Moment (emu)']*1e8,'name':'TRM5','mode':'markers+lines'},
       {"x":TRM2['Temperature (K)'],"y":TRM2['Long Moment (emu)']*1e8,'name':'TRM2','mode':'markers+lines'},
       {"x":TRM5Sapph['Temperature (K)'],"y":TRM5Sapph['Long Moment (emu)']*1e8,'name':'TRM5SapphireHolder','mode':'markers+lines'},
       {"x":TRM2Sapph['Temperature (K)'],"y":TRM2Sapph['Long Moment (emu)']*1e8,'name':'TRM2SapphireHolder','mode':'markers+lines'}
       ])
# Out:
# <div id="d7ac918a-af09-4e41-9599-bf89ebfba353" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d7ac918a-af09-4e41-9599-bf89ebfba353", [{"x": [22.000239999999998, 23.2185, 24.01822, 24.82157, 25.61672, 26.421329999999998, 27.253690000000002, 28.04605, 28.8513, 29.68372, 30.470940000000002, 31.268209999999996, 32.11991, 32.90609, 33.71627, 34.55937, 35.32502, 36.12659, 36.96402, 37.73985, 38.55648, 39.39141, 40.18201, 40.99223, 41.81438, 42.92288, 43.730090000000004, 44.55563, 45.342940000000006, 46.13694, 46.95139, 47.746559999999995, 48.54225, 49.35935, 50.140840000000004, 50.94031, 51.7504, 52.520990000000005, 53.30115, 54.10921999999999, 54.89487, 55.675540000000005, 56.48771, 57.2731, 58.06031, 58.85698000000001, 59.63691, 60.01079, 59.99839, 60.8732, 61.46912, 62.047090000000004, 62.61946, 63.1
# ...

# %%
iplot([{"x":FC2['Temperature (K)'],"y":FC2['Long Moment (emu)']*1e8,'name':'FC2','mode':'markers+lines'},
       {"x":TRM2['Temperature (K)'],"y":TRM2['Long Moment (emu)']*1e8,'name':'TRM2','mode':'markers+lines'}])
# Out:
# <div id="a58bdc77-fa11-425e-82dc-8ea9793ac091" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a58bdc77-fa11-425e-82dc-8ea9793ac091", [{"x": [177.0023, 176.4158, 176.072, 175.7129, 175.2955, 174.87, 174.4844, 174.0814, 173.6579, 173.2623, 172.8408, 172.4398, 172.0435, 171.6642, 171.2487, 170.8404, 170.4132, 170.0102, 169.636, 169.2364, 168.7858, 168.4291, 167.9901, 167.6172, 167.2076, 166.8229, 166.3991, 165.9938, 165.6193, 165.2008, 164.8094, 164.3954, 164.0156, 163.5896, 163.1968, 162.7952, 162.4086, 161.991, 161.5721, 161.2073, 160.7949, 160.4005, 160.0011, 159.5933, 159.1943, 158.7881, 158.3855, 157.9917, 157.5832, 157.1873, 156.7939, 156.3829, 155.9722, 155.5836, 155.1684, 154.7796, 154.3869, 153.9877, 153.5815, 153.1885, 152.7773, 152.3803, 151.9741, 151.5792, 151.1842, 150.7656, 150.3816, 14
# ...

# %%
iplot([{"x":FC5['Temperature (K)'],"y":FC5['Long Moment (emu)']*1e8,'name':'FC5','mode':'markers+lines'},
       {"x":TRM5['Temperature (K)'],"y":TRM5['Long Moment (emu)']*1e8,'name':'TRM5','mode':'markers+lines'}])
# Out:
# <div id="db1a3380-7870-420a-abd6-547ea9f5c79d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("db1a3380-7870-420a-abd6-547ea9f5c79d", [{"x": [154.9995, 154.2602, 153.7392, 153.1874, 152.5903, 152.0277, 151.457, 150.8808, 150.3216, 149.7584, 149.1957, 148.6337, 148.0765, 147.5126, 146.9497, 146.3814, 145.8204, 145.2625, 144.701, 144.1326, 143.5732, 143.0139, 142.4546, 141.8866, 141.3356, 140.7716, 140.2059, 139.6419, 139.0994, 138.5328, 137.9666, 137.4035, 136.8502, 136.2994, 135.7296, 135.1568, 134.6012, 134.0428, 133.4989, 132.913, 132.3744, 131.8076, 131.2583, 130.6881, 130.1302, 129.577, 129.0131, 128.4402, 127.8846, 127.3326, 126.7763, 126.2022, 125.6465, 125.0848, 124.5243, 123.9504, 123.3821, 122.8139, 122.2425, 121.6536, 121.0871, 120.5211, 119.9469, 119.3589, 118.7812, 118.196, 117.6245, 11
# ...

# %%
iplot([{"x":FC5Sapph['Temperature (K)'],"y":FC5Sapph['Long Moment (emu)']*1e8,'name':'FC5SapphireHolder','mode':'markers+lines'},
       {"x":TRM5Sapph['Temperature (K)'],"y":TRM5Sapph['Long Moment (emu)']*1e8,'name':'TRM5SapphireHolder','mode':'markers+lines'}])
# Out:
# <div id="9f2fa9c8-f21b-454c-af67-876878b8f835" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9f2fa9c8-f21b-454c-af67-876878b8f835", [{"x": [154.9992, 154.2922, 153.6866, 153.1874, 152.6035, 152.0286, 151.4514, 150.8993, 150.3242, 149.7704, 148.5477, 148.0739, 147.5126, 146.9365, 146.383, 145.8248, 145.2618, 144.69, 144.1374, 143.5784, 143.0336, 142.0674, 141.533, 141.0362, 140.5329, 140.0125, 139.5026, 138.9873, 138.4756, 137.9427, 137.4232, 136.8483, 136.2851, 135.7301, 135.0979, 134.4006, 133.8801, 133.3295, 132.7902, 132.2439, 131.6949, 131.1411, 130.5997, 130.048, 129.5055, 128.9442, 128.4049, 127.8467, 127.2857, 126.7171, 126.1594, 125.6021, 125.048, 124.4782, 123.9235, 123.3718, 122.8028, 122.2393, 121.6706, 121.1078, 120.5451, 119.9648, 119.3929, 118.8145, 118.2586, 117.6747, 117.0301, 116
# ...

# %%
iplot([{"x":m1kOe['Temperature (K)'],"y": m1kOe['Long Moment (emu)']*1e8,'name':'m1kOe','mode':'markers+lines'}])
# Out:
# <div id="f4482e36-8f8f-45fb-9db4-28ca34f25d0b" style="height: 525; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f4482e36-8f8f-45fb-9db4-28ca34f25d0b", [{"name": "m1kOe", "mode": "markers+lines", "y": [-380.8233, -380.3521, -380.9942, -380.4774, 1786.5510000000002, 1786.453, 1786.729, 1786.9170000000004, -380.2594, -380.7111, -380.4253, -380.9647, -380.5357, -380.9621, -381.2687], "x": [154.9954, 154.9979, 154.9989, 154.9978, 22.001379999999997, 22.001379999999997, 22.0004, 21.99991, 154.9996, 155.0013, 155.002, 154.9996, 155.001, 154.9989, 155.0006]}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>
